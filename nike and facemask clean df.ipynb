# %%
import pandas as pd
import numpy as np

# %%
nike_df = pd.read_csv('nike_reviews1.csv')

# %%
nike_df['sentiment'] = nike_df['ratings'].apply(lambda x: 0 if int(x) <= 3 else 1)

nike_df
# Out:
#      ratings                                            reviews  \
# 0          5                               I like how they look
# 1          1  Shoes came USED & ABUSED!These shoes came out ...
# 2          1  I haven't worn these on a real regular basis b...
# 3          1  I’m an Airmax fanatic, love the style and comf...
# 4          1  Don't pay retail for fake shoes. They are so u...
# ..       ...                                                ...
# 402        2       Not buying that no weonder it sells for less
# 403        5          These shoes fit perfect and are stunning!
# 404        5                              He love it my husband
# 405        4                                         Great shoe
# 406        5          Arrived Fast and My hubby loved them!!!!!
#
#      Whistleblower  sentiment
# 0              0.0          1
# 1              0.0          0
# 2              0.0          0
# 3              0.0          0
# 4              1.0          0
# ...

# %%
facemask_df = pd.read_csv('facemask_reviews1.csv')

# %%
facemask_df['sentiment'] = facemask_df['rating'].apply(lambda x: 0 if int(x) <= 3 else 1)

facemask_df
# Out:
#      rating                                            reviews  \
# 0         5  This blackhead mask is very easy to be put on ...
# 1         5  That is actually a good product, my fair and h...
# 2         5  I love blakchead mask. I use my hand to apply ...
# 3         5  Love this product!! For the price I would buy ...
# 4         5  I can always appreciate a peel off mask that d...
# ..      ...                                                ...
# 321       5  I really enjoyed the black mask. It pulled out...
# 322       5  I made a full face mask and it did tingle a li...
# 323       5  It's a great addition to my weekend spa day ro...
# 324       5  I only used it once and I’ll use it again. Aft...
# 325       1  Do not use at all cost! Used one day, and had ...
#
#      Whistleblower   sentiment
# 0               0.0          1
# 1               0.0          1
# 2               0.0          1
# 3               0.0          1
# 4               0.0          1
# ...

# %%
facemask_df.to_csv('facemask_reviews_updated.csv')
